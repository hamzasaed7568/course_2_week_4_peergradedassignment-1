# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **hamza saeed**
#
# Data Scientist

# %% [markdown]
# _i am interested in data science becuase the data driven decision making provides us the best solution from personal to professional life. Data science play a important role in the betterment of society and industry whether it is tech, health, business etc._

# %% [markdown]
# ### My program generate a table based on the number provided by the user

# %%
num = input("enter number: ")
num = int(num)
for i in range(1,11):
    print(f"{num} x  {i}  = ",num*i)
# Out:
# enter number: 2
# 2 x  1  =  2
# 2 x  2  =  4
# 2 x  3  =  6
# 2 x  4  =  8
# 2 x  5  =  10
# 2 x  6  =  12
# 2 x  7  =  14
# 2 x  8  =  16
# 2 x  9  =  18
# 2 x  10  =  20

# %% [markdown]
# ***
# - task 1 done
# - task 2 done
# - task 3 done
# - task 4 done
# - task 5 done
# - task 6 done
# ***
# 1. task 1 done
# 2. task 2 done
# 3. task 3 done
# 4. task 4 done
# 5. task 5 done
# 6. task 6 done
# ***
